# %%
from minitorch.tensor.tensor import Tensor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from minitorch.tensor.tensor import Tensor
#
# ModuleNotFoundError: No module named 'minitorch'
